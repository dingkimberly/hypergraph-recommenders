# %%
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)
import matplotlib.pyplot as plt

# %%
probs = np.linspace(0, 1, num=11)

e1_hg = [0.94940453, 0.89848693, 0.82704067, 0.74324467, 0.62540733,
       0.49242613, 0.36750067, 0.26243267, 0.18223187, 0.13549627,
       0.10881147]
e2_hg = [0.94940453, 0.90492933, 0.84245187, 0.75246173, 0.6328692 ,
       0.50107053, 0.3698528 , 0.2556104 , 0.1741616 , 0.12265107,
       0.0921452 ]
e3_hg = [0.94940453, 0.9404888 , 0.93150493, 0.922684  , 0.9099368 ,
       0.89168893, 0.8604868 , 0.80022707, 0.69785333, 0.53871467,
       0.        ]

e1_hg_u = [0.9945177 , 0.9662201 , 0.90067333, 0.80509172, 0.65915388,
       0.48615968, 0.32233435, 0.1860325 , 0.08533305, 0.03223491,
       0.00824078]
e2_hg_u = [0.9945177 , 0.97265209, 0.92024541, 0.82033433, 0.67180449,
       0.50135154, 0.33004967, 0.18215345, 0.08144394, 0.02601919,
       0.00355345]
e3_hg_u = [0.9945177 , 0.99160386, 0.98671406, 0.97918676, 0.96451392,
       0.93961596, 0.89910315, 0.82580012, 0.70959501, 0.53975818,
       0.        ]

e1_g = [0.877446  , 0.85307467, 0.8157572 , 0.76803493, 0.69882947,
       0.61151493, 0.5110576 , 0.40563053, 0.2995676 , 0.2154764 ,
       0.15916573]
e2_g = [0.877446  , 0.8507576 , 0.8032096 , 0.72592107, 0.6190004 ,
       0.5016388 , 0.38112947, 0.2744768 , 0.19630067, 0.14760333,
       0.12108453]
e3_g = [0.877446  , 0.88087853, 0.8834332 , 0.88397053, 0.87412773,
       0.84958547, 0.80424573, 0.72571493, 0.61913453, 0.51426307,
       0.        ]

e1_g_u = [0.99270582, 0.96751921, 0.91912597, 0.85440711, 0.75933224,
       0.63848409, 0.49910307, 0.35271921, 0.20560955, 0.08893313,
       0.01083144]
e2_g_u = [0.99270582, 0.965318  , 0.90493743, 0.80225218, 0.65915387,
       0.50204616, 0.34071286, 0.19799605, 0.09427907, 0.03231989,
       0.0049148 ]
e3_g_u = [0.99270582, 0.98899914, 0.98204131, 0.97087387, 0.94664799,
       0.90568451, 0.84300435, 0.74679472, 0.6263997 , 0.51489551,
       0.        ]

e2_h = [0.98479867, 0.97261227, 0.960958  , 0.95070373, 0.94081907,
       0.9324176 , 0.9242788 , 0.916418  , 0.90895613, 0.90160147,
       0.8930472 ]
e3_h = [0.98479867, 0.9834248 , 0.98145413, 0.98032627, 0.9792944 ,
       0.9796572 , 0.9800016 , 0.98046133, 0.98010347, 0.9669964 ,
       0.83]

e2_h_u = [0.99663125, 0.99663125, 0.996623  , 0.99661766, 0.99659256,
       0.99656019, 0.99650766, 0.99633442, 0.99596891, 0.9951256 ,
       0.99251974]
e3_h_u = [0.99663125, 0.99663125, 0.99646684, 0.99627953, 0.99592687,
       0.99517071, 0.99434738, 0.99247947, 0.98851915, 0.9704159 ,
       0.83043356]

# %%
plt.scatter(probs, e1_hg)
plt.scatter(probs, e1_g)
plt.plot(probs, e1_hg, label='Hypergraph')
plt.plot(probs, e1_g, label='Graph')
plt.legend(loc='lower left')
plt.xlabel('Probability of reversed edge weight')
plt.ylabel('DOA')
plt.show()

# %%
plt.scatter(probs, e1_hg_u)
plt.scatter(probs, e1_g_u)
plt.plot(probs, e1_hg_u, label='Hypergraph')
plt.plot(probs, e1_g_u, label='Graph')
plt.legend(loc='lower left')
plt.xlabel('Probability of reversed edge weight')
plt.ylabel('UDOA')
plt.show()

# %%
plt.scatter(probs, e2_hg)
plt.scatter(probs, e2_g)
#plt.scatter(probs, e2_h)
plt.plot(probs, e2_hg, label='Hypergraph')
plt.plot(probs, e2_g, label='Graph')
#plt.plot(probs, e2_h, label='Hybrid')
plt.legend(loc='lower left')
plt.xlabel('Probability of reversed edge-dependent vertex weight')
plt.ylabel('DOA')
plt.show()

# %%
plt.scatter(probs, e2_hg_u)
plt.scatter(probs, e2_g_u)
#plt.scatter(probs, e2_h_u)
plt.plot(probs, e2_hg_u, label='Hypergraph')
plt.plot(probs, e2_g_u, label='Graph')
#plt.plot(probs, e2_h_u, label='Hybrid')
plt.legend(loc='lower left')
plt.xlabel('Probability of reversed edge-dependent vertex weight')
plt.ylabel('UDOA')
plt.show()

# %%
plt.scatter(probs, e3_hg)
plt.scatter(probs, e3_g)
#plt.scatter(probs, e3_h)
plt.plot(probs, e3_hg, label='Hypergraph')
plt.plot(probs, e3_g, label='Graph')
#plt.plot(probs, e3_h, label='Hybrid')
plt.legend(loc='lower left')
plt.xlabel('Probability of erased edge-dependent vertex weight')
plt.ylabel('DOA')
plt.show()

# %%
plt.scatter(probs, e3_hg_u)
plt.scatter(probs, e3_g_u)
#plt.scatter(probs, e3_h_u)
plt.plot(probs, e3_hg_u, label='Hypergraph')
plt.plot(probs, e3_g_u, label='Graph')
#plt.plot(probs, e3_h_u, label='Hybrid')
plt.legend(loc='lower left')
plt.xlabel('Probability of erased edge-dependent vertex weight')
plt.ylabel('UDOA')
plt.show()

# %% [markdown]
# The hybrid's performance is suspiciously high. I think it may have been too powerful of a hypergraph.
